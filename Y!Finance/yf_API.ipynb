# %%
import yfinance as yf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
msft = yf.Ticker("MSFT")
msft
# Out:
# yfinance.Ticker object <MSFT>

# %%
# get all stock info
msft.info
# Out:
# {'address1': 'One Microsoft Way',
#  'city': 'Redmond',
#  'state': 'WA',
#  'zip': '98052-6399',
#  'country': 'United States',
#  'phone': '425 882 8080',
#  'fax': '425 706 7329',
#  'website': 'https://www.microsoft.com',
#  'industry': 'Software—Infrastructure',
#  'sector': 'Technology',
#  'longBusinessSummary': 'Microsoft Corporation develops, licenses, and supports software, services, devices, and solutions worldwide. The company operates in three segments: Productivity and Business Processes, Intelligent Cloud, and More Personal Computing. The Productivity and Business Processes segment offers Office, Exchange, SharePoint, Microsoft Teams, Office 365 Security and Compliance, Microsoft Viva, and Skype for Business; Skype, Outlook.com, OneDrive, and LinkedIn; and Dynamics 365, a set of cloud-based and on-premises business solutions for organizations and enterprise divisions. The Intelligent Cloud segment licenses SQL, Windows Servers, Visual Studio, System Center, and related Client Access Licenses; GitHub that provides a collaboration platform and code hosting service for developers; Nuance provides healthcare and enterprise AI solutions; and Azure, a cloud platform. It also offers enterprise support, Microsoft consulting, and nuance professional services to assist customers in developing, deploying, and managing Microsoft server and desktop solutions; and training and certification on Microsoft products. The More Personal Computing segment provides Windows original equipment manufacturer (OEM) licensing and other non-volume licensing of the Windows operating system; Windows Commercial, such as volume licensing of the Windows operating system, Windows cloud services, and other Windows commercial offerings; patent licensing; and Windows Internet of Things. It also offers Surface, PC accessories, PCs, tablets, gaming and entertainment consoles, and other devices; Gaming, including Xbox hardware, and Xbox content and services; video games and third-party video game royalties; and Search, including Bing and Microsoft advertising. The company sells its products through OEMs, distributors, and resellers; and directly through digital marketplaces, online stores, and retail stores. Microsoft Corporation was founded in 1975 and is headquartered in Redmond, Washington.',
#  'fullTimeEmployees': 221000,
#  'companyOfficers': [{'maxAge': 1,
#    'name': 'Mr. Satya  Nadella',
#    'age': 55,
#    'title': 'Chairman & CEO',
#    'yearBorn': 1967,
#    'fiscalYear': 2022,
#    'totalPay': 12676750,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Bradford L. Smith LCA',
#    'age': 63,
#    'title': 'Pres & Vice Chairman',
#    'yearBorn': 1959,
#    'fiscalYear': 2022,
#    'totalPay': 4655274,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Amy E. Hood',
#    'age': 50,
#    'title': 'Exec. VP & CFO',
#    'yearBorn': 1972,
#    'fiscalYear': 2022,
#    'totalPay': 4637915,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Judson  Althoff',
#    'age': 49,
#    'title': 'Exec. VP & Chief Commercial Officer',
#    'yearBorn': 1973,
#    'fiscalYear': 2022,
#    'totalPay': 4428268,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Christopher David Young',
#    'age': 50,
#    'title': 'Exec. VP of Bus. Devel., Strategy & Ventures',
#    'yearBorn': 1972,
#    'fiscalYear': 2022,
#    'totalPay': 4588876,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Alice L. Jolla',
#    'age': 55,
#    'title': 'Corp. VP & Chief Accounting Officer',
#    'yearBorn': 1967,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Brett  Iversen',
#    'title': 'Gen. Mang. of Investor Relations',
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Frank X. Shaw',
#    'title': 'Corp. VP for Corp. Communications',
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Christopher C. Capossela',
#    'age': 52,
#    'title': 'Exec. VP & Chief Marketing Officer',
#    'yearBorn': 1970,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Keith Ranger Dolliver Esq.',
#    'title': 'VP, Deputy Gen. Counsel of Corp., External & Legal Affairs and Assistant Sec.',
#    'exercisedValue': 0,
#    'unexercisedValue': 0}],
#  'auditRisk': 5,
#  'boardRisk': 5,
#  'compensationRisk': 2,
#  'shareHolderRightsRisk': 2,
#  'overallRisk': 2,
#  'governanceEpochDate': 1680307200,
#  'compensationAsOfEpochDate': 1672444800,
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 289.39,
#  'open': 285.75,
#  'dayLow': 281.64,
#  'dayHigh': 285.87,
#  'regularMarketPreviousClose': 289.39,
#  'regularMarketOpen': 285.75,
#  'regularMarketDayLow': 281.64,
#  'regularMarketDayHigh': 285.87,
#  'dividendRate': 2.72,
#  'dividendYield': 0.0094,
#  'exDividendDate': 1684281600,
#  'payoutRatio': 0.28219998,
#  'fiveYearAvgDividendYield': 1.12,
#  'beta': 0.915117,
#  'trailingPE': 31.425554,
#  'forwardPE': 26.309767,
#  'volume': 27276589,
#  'regularMarketVolume': 27276589,
#  'averageVolume': 31871231,
#  'averageVolume10days': 25765990,
#  'averageDailyVolume10Day': 25765990,
#  'bid': 282.94,
#  'ask': 283.13,
#  'bidSize': 900,
#  'askSize': 800,
#  'marketCap': 2105329844224,
#  'fiftyTwoWeekLow': 213.43,
#  'fiftyTwoWeekHigh': 294.18,
#  'priceToSalesTrailing12Months': 10.315492,
#  'fiftyDayAverage': 265.6484,
#  'twoHundredDayAverage': 254.30965,
#  'trailingAnnualDividendRate': 2.6,
#  'trailingAnnualDividendYield': 0.008984415,
#  'currency': 'USD',
#  'enterpriseValue': 2132652326912,
#  'profitMargins': 0.33048,
#  'floatShares': 7436955234,
#  'sharesOutstanding': 7443800064,
#  'sharesShort': 35907039,
#  'sharesShortPriorMonth': 36520392,
#  'sharesShortPreviousMonthDate': 1676419200,
#  'dateShortInterest': 1678838400,
#  'sharesPercentSharesOut': 0.0047999998,
#  'heldPercentInsiders': 0.00057,
#  'heldPercentInstitutions': 0.73654,
#  'shortRatio': 1.3,
#  'shortPercentOfFloat': 0.0047999998,
#  'impliedSharesOutstanding': 0,
#  'bookValue': 24.592,
#  'priceToBook': 11.500895,
#  'lastFiscalYearEnd': 1656547200,
#  'nextFiscalYearEnd': 1688083200,
#  'mostRecentQuarter': 1672444800,
#  'earningsQuarterlyGrowth': -0.125,
#  'netIncomeToCommon': 67448999936,
#  'trailingEps': 9.0,
#  'forwardEps': 10.75,
#  'pegRatio': 2.55,
#  'lastSplitFactor': '2:1',
#  'lastSplitDate': 1045526400,
#  'enterpriseToRevenue': 10.449,
#  'enterpriseToEbitda': 21.774,
#  '52WeekChange': -0.016653895,
#  'SandP52WeekChange': -0.07593459,
#  'lastDividendValue': 0.68,
#  'lastDividendDate': 1676419200,
#  'exchange': 'NMS',
#  'quoteType': 'EQUITY',
#  'symbol': 'MSFT',
#  'underlyingSymbol': 'MSFT',
#  'shortName': 'Microsoft Corporation',
#  'longName': 'Microsoft Corporation',
#  'firstTradeDateEpochUtc': 511108200,
#  'timeZoneFullName': 'America/New_York',
#  'timeZoneShortName': 'EDT',
#  'uuid': 'b004b3ec-de24-385e-b2c1-923f10d3fb62',
#  'messageBoardId': 'finmb_21835',
#  'gmtOffSetMilliseconds': -14400000,
#  'currentPrice': 282.83,
#  'targetHighPrice': 348.0,
#  'targetLowPrice': 212.0,
#  'targetMeanPrice': 291.24,
#  'targetMedianPrice': 291.0,
#  'recommendationMean': 1.9,
#  'recommendationKey': 'buy',
#  'numberOfAnalystOpinions': 45,
#  'totalCash': 99495002112,
#  'totalCashPerShare': 13.366,
#  'ebitda': 97945001984,
#  'totalDebt': 77984997376,
#  'quickRatio': 1.656,
#  'currentRatio': 1.931,
#  'totalRevenue': 204093997056,
#  'debtToEquity': 42.583,
#  'revenuePerShare': 27.327,
#  'returnOnAssets': 0.14826,
#  'returnOnEquity': 0.39312,
#  'grossProfits': 135620000000,
#  'freeCashflow': 44613373952,
#  'operatingCashflow': 84385996800,
#  'earningsGrowth': -0.113,
#  'revenueGrowth': 0.02,
#  'grossMargins': 0.68160003,
#  'ebitdaMargins': 0.4799,
#  'operatingMargins': 0.40969002,
#  'financialCurrency': 'USD',
#  'trailingPegRatio': 2.1914}

# %%
# get historical market data
hist = msft.history(period="1mo")
type(hist) # DataFrame

hist
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2023-03-13 00:00:00-04:00  247.399994  257.910004  245.729996  253.919998
# 2023-03-14 00:00:00-04:00  256.750000  261.070007  255.860001  260.790009
# 2023-03-15 00:00:00-04:00  259.980011  266.480011  259.209991  265.440002
# 2023-03-16 00:00:00-04:00  265.209991  276.559998  263.279999  276.200012
# 2023-03-17 00:00:00-04:00  278.260010  283.329987  276.320007  279.429993
# 2023-03-20 00:00:00-04:00  276.980011  277.480011  269.850006  272.230011
# 2023-03-21 00:00:00-04:00  274.880005  275.000000  269.519989  273.779999
# 2023-03-22 00:00:00-04:00  273.399994  281.040009  272.179993  272.290009
# 2023-03-23 00:00:00-04:00  277.940002  281.059998  275.200012  277.660004
# 2023-03-24 00:00:00-04:00  277.239990  280.630005  275.279999  280.570007
# 2023-03-27 00:00:00-04:00  280.500000  281.459991  275.519989  276.380005
# 2023-03-28 00:00:00-04:00  275.790009  276.140015  272.049988  275.230011
# 2023-03-29 00:00:00-04:00  278.959991  281.140015  278.410004  280.510010
# 2023-03-30 00:00:00-04:00  284.230011  284.459991  281.480011  284.049988
# 2023-03-31 00:00:00-04:00  283.730011  289.269989  283.000000  288.299988
# 2023-04-03 00:00:00-04:00  286.519989  288.269989  283.950012  287.230011
# 2023-04-04 00:00:00-04:00  287.230011  290.450012  285.670013  287.179993
# 2023-04-05 00:00:00-04:00  285.850006  287.149994  282.920013  284.339996
# 2023-04-06 00:00:00-04:00  283.209991  292.079987  282.029999  291.600006
# 2023-04-10 00:00:00-04:00  289.209991  289.600006  284.709991  289.390015
# 2023-04-11 00:00:00-04:00  285.750000  285.980011  281.640015  282.829987
#
#                              Volume  Dividends  Stock Splits
# Date
# 2023-03-13 00:00:00-04:00  33339700        0.0           0.0
# 2023-03-14 00:00:00-04:00  33620300        0.0           0.0
# 2023-03-15 00:00:00-04:00  46028000        0.0           0.0
# 2023-03-16 00:00:00-04:00  54768800        0.0           0.0
# 2023-03-17 00:00:00-04:00  69527400        0.0           0.0
# 2023-03-20 00:00:00-04:00  43466600        0.0           0.0
# 2023-03-21 00:00:00-04:00  34558700        0.0           0.0
# 2023-03-22 00:00:00-04:00  34873300        0.0           0.0
# 2023-03-23 00:00:00-04:00  36610900        0.0           0.0
# 2023-03-24 00:00:00-04:00  28172000        0.0           0.0
# 2023-03-27 00:00:00-04:00  26840200        0.0           0.0
# 2023-03-28 00:00:00-04:00  21878600        0.0           0.0
# 2023-03-29 00:00:00-04:00  25087000        0.0           0.0
# 2023-03-30 00:00:00-04:00  25053400        0.0           0.0
# 2023-03-31 00:00:00-04:00  32740300        0.0           0.0
# 2023-04-03 00:00:00-04:00  24883300        0.0           0.0
# 2023-04-04 00:00:00-04:00  25824300        0.0           0.0
# 2023-04-05 00:00:00-04:00  22064800        0.0           0.0
# 2023-04-06 00:00:00-04:00  29770300        0.0           0.0
# 2023-04-10 00:00:00-04:00  23103000        0.0           0.0
# 2023-04-11 00:00:00-04:00  27254900        0.0           0.0

# %%
# show meta information about the history (requires history() to be called first)
msft.history_metadata
# Out:
# {'currency': 'USD',
#  'symbol': 'MSFT',
#  'exchangeName': 'NMS',
#  'instrumentType': 'EQUITY',
#  'firstTradeDate': Timestamp('1986-03-13 09:30:00-0500', tz='America/New_York'),
#  'regularMarketTime': Timestamp('2023-04-11 16:00:04-0400', tz='America/New_York'),
#  'gmtoffset': -14400,
#  'timezone': 'EDT',
#  'exchangeTimezoneName': 'America/New_York',
#  'regularMarketPrice': 282.83,
#  'chartPreviousClose': 248.59,
#  'priceHint': 2,
#  'currentTradingPeriod': {'pre': {'start': Timestamp('2023-04-11 04:00:00-0400', tz='America/New_York'),
#    'end': Timestamp('2023-04-11 09:30:00-0400', tz='America/New_York')},
#   'regular': {'start': Timestamp('2023-04-11 09:30:00-0400', tz='America/New_York'),
#    'end': Timestamp('2023-04-11 16:00:00-0400', tz='America/New_York')},
#   'post': {'start': Timestamp('2023-04-11 16:00:00-0400', tz='America/New_York'),
#    'end': Timestamp('2023-04-11 20:00:00-0400', tz='America/New_York')}},
#  'dataGranularity': '1d',
#  'range': '1mo',
#  'validRanges': ['1d',
#   '5d',
#   '1mo',
#   '3mo',
#   '6mo',
#   '1y',
#   '2y',
#   '5y',
#   '10y',
#   'ytd',
#   'max']}

# %%
# show actions (dividends, splits, capital gains)
#msft.actions,
#msft.dividends,
#msft.splits,
#msft.capital_gains, # only for mutual funds & etfs
# Out:
# (Series([], Name: Dividends, dtype: float64),)

# %%
# show share count
# - yearly summary:
#msft.shares

# %%
# - accurate time-series count:
msft.get_shares_full(start="2022-01-01", end=None)
# Out:
# 2022-01-27 00:00:00-05:00    7496869888
# 2022-02-04 00:00:00-05:00    7800719872
# 2022-02-05 00:00:00-05:00    7496869888
# 2022-02-11 00:00:00-05:00    7496869888
# 2022-03-04 00:00:00-05:00    7605040128
# 2022-03-05 00:00:00-05:00    7496869888
# 2022-03-16 00:00:00-04:00    7595310080
# 2022-03-17 00:00:00-04:00    7496869888
# 2022-03-28 00:00:00-04:00    7507230208
# 2022-03-31 00:00:00-04:00    7496869888
# 2022-04-01 00:00:00-04:00    7631819776
# 2022-04-02 00:00:00-04:00    7496869888
# 2022-04-04 00:00:00-04:00    7496869888
# 2022-04-29 00:00:00-04:00    7479029760
# 2022-06-09 00:00:00-04:00    7536840192
# 2022-06-13 00:00:00-04:00    7479029760
# 2022-07-28 00:00:00-04:00    7464000000
# 2022-08-01 00:00:00-04:00    7457889792
# 2022-08-25 00:00:00-04:00    7475469824
# 2022-08-26 00:00:00-04:00    7457889792
# 2022-09-01 00:00:00-04:00    7457889792
# 2022-09-02 00:00:00-04:00    7488540160
# 2022-09-02 00:00:00-04:00    7457889792
# 2022-09-10 00:00:00-04:00    7290379776
# 2022-09-12 00:00:00-04:00    7457889792
# 2022-09-15 00:00:00-04:00    7451089920
# 2022-09-15 00:00:00-04:00    7457889792
# 2022-09-16 00:00:00-04:00    7665780224
# 2022-09-16 00:00:00-04:00    7457889792
# 2022-09-17 00:00:00-04:00    7457889792
# 2022-09-17 00:00:00-04:00    7477389824
# 2022-10-29 00:00:00-04:00    7454470144
# 2023-01-04 00:00:00-05:00    7461940224
# 2023-01-06 00:00:00-05:00    7454470144
# 2023-01-27 00:00:00-05:00    7443800064
# 2023-03-08 00:00:00-05:00    7523469824
# 2023-03-08 00:00:00-05:00    7443800064
# 2023-03-10 00:00:00-05:00    7443800064
# 2023-03-10 00:00:00-05:00    7484519936
# 2023-03-30 00:00:00-04:00    7586610176
# 2023-04-01 00:00:00-04:00    7443800064
# 2023-04-01 00:00:00-04:00    7555180032
# 2023-04-04 00:00:00-04:00    7471529984
# 2023-04-05 00:00:00-04:00    7443800064
# 2023-04-06 00:00:00-04:00    7518150144
# 2023-04-07 00:00:00-04:00    7443800064
# dtype: int64

# %%
# show financials:
# - income statement
#msft.income_stmt
#msft.quarterly_income_stmt

# %%
# - balance sheet
#msft.balance_sheet
#msft.quarterly_balance_sheet

# %%
# - cash flow statement
#msft.cashflow
#msft.quarterly_cashflow
# see `Ticker.get_income_stmt()` for more options

# %%
# show holders
msft.major_holders
msft.institutional_holders
msft.mutualfund_holders
# Out:
#                                               Holder     Shares Date Reported  \
# 0             Vanguard Total Stock Market Index Fund  222313847    2022-09-29
# 1                            Vanguard 500 Index Fund  169062762    2022-09-29
# 2                             SPDR S&P 500 ETF Trust   82250000    2022-12-30
# 3                            Fidelity 500 Index Fund   81679555    2022-12-30
# 4        Invesco ETF Tr-Invesco QQQ Tr, Series 1 ETF   76335623    2022-12-30
# 5                           iShares Core S&P 500 ETF   66940817    2022-12-30
# 6                         Vanguard Growth Index Fund   61426549    2022-09-29
# 7  Vanguard Institutional Index Fund-Institutiona...   54149972    2022-09-29
# 8                         Growth Fund Of America Inc   44491127    2022-12-30
# 9                 Select Sector SPDR Fund-Technology   34910084    2022-12-30
#
#     % Out        Value
# 0  0.0299  62877022361
# 1  0.0227  47816018706
# 2  0.0110  23262766395
# 3  0.0110  23101427443
# 4  0.0103  21590003228
# 5  0.0090  18932870373
# 6  0.0083  17373270028
# 7  0.0073  15315235853
# 8  0.0060  12583424851
# 9  0.0047   9873618588

# %%
# show earnings
msft.earnings
msft.quarterly_earnings
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# show sustainability
# msft.sustainability

# %%
# show analysts recommendations
msft.recommendations
msft.recommendations_summary

# %%
# show analysts other work
# msft.analyst_price_target
msft.revenue_forecasts
msft.earnings_forecasts
msft.earnings_trend

# %%
# show next event (earnings, etc)
msft.calendar

# %%
# Show future and historic earnings dates, returns at most next 4 quarters and last 8 quarters by default.
# Note: If more are needed use msft.get_earnings_dates(limit=XX) with increased limit argument.
msft.earnings_dates
# Out:
#                            EPS Estimate  Reported EPS  Surprise(%)
# Earnings Date
# 2024-01-22 16:00:00-05:00           NaN           NaN          NaN
# 2024-01-22 05:00:00-05:00           NaN           NaN          NaN
# 2023-10-23 06:00:00-04:00           NaN           NaN          NaN
# 2023-07-24 06:00:00-04:00           NaN           NaN          NaN
# 2023-04-24 06:00:00-04:00          2.23           NaN          NaN
# 2023-01-24 11:00:00-05:00          2.30          2.32       0.0109
# 2022-10-25 12:00:00-04:00          2.30          2.35       0.0204
# 2022-07-26 12:00:00-04:00          2.29          2.23      -0.0275
# 2022-04-26 12:00:00-04:00          2.19          2.22       0.0160
# 2022-01-25 11:00:00-05:00          2.31          2.48       0.0727
# 2021-10-26 12:00:00-04:00          2.08          2.27       0.0940
# 2021-07-27 12:00:00-04:00          1.92          2.17       0.1326

# %%
# show ISIN code - *experimental*
# ISIN = International Securities Identification Number
msft.isin
# Out:
# '-'

# %%
# show options expirations
msft.options
# Out:
# ('2023-04-14',
#  '2023-04-21',
#  '2023-04-28',
#  '2023-05-05',
#  '2023-05-12',
#  '2023-05-19',
#  '2023-05-26',
#  '2023-06-16',
#  '2023-07-21',
#  '2023-08-18',
#  '2023-09-15',
#  '2023-10-20',
#  '2023-11-17',
#  '2024-01-19',
#  '2024-03-15',
#  '2024-06-21',
#  '2024-12-20',
#  '2025-01-17',
#  '2025-06-20',
#  '2025-12-19')

# %%
# show news
msft.news
# Out:
# [{'uuid': 'fe66b40c-8c59-3103-9b14-70371ba91eb1',
#   'title': 'Dow Jones Futures: Market Rally Fades, But These 4 Stocks Flash Buy Signals; Inflation Report Due',
#   'publisher': "Investor's Business Daily",
#   'link': 'https://finance.yahoo.com/m/fe66b40c-8c59-3103-9b14-70371ba91eb1/dow-jones-futures%3A-market.html',
#   'providerPublishTime': 1681265331,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/DHqiTSZdrBORfA0AMV0vQA--~B/aD01NjM7dz0xMDAwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/ibd.com/e9593b7778279b222a3c82aa5085f4f0',
#      'width': 1000,
#      'height': 563,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/Sak9xpN8Z7MUomA54jeLRw--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/ibd.com/e9593b7778279b222a3c82aa5085f4f0',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['^GSPC',
#    'COMP',
#    '^DJI',
#    '^RUT',
#    'SWAV',
#    'MSFT',
#    'SKX',
#    'AMZN',
#    'DHI',
#    'GOOGL']},
#  {'uuid': 'a04c4364-6fe1-389a-8691-50585a977d3b',
#   'title': 'What Is ChatGPT? What to Know About the AI Chatbot',
#   'publisher': 'The Wall Street Journal',
#   'link': 'https://finance.yahoo.com/m/a04c4364-6fe1-389a-8691-50585a977d3b/what-is-chatgpt%3F-what-to-know.html',
#   'providerPublishTime': 1681260240,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/NfJKrYxbN.n9BgewSxTkbw--~B/aD02NDA7dz0xMjgwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/wsj.com/997ad226ccbc25e4a5edead9637689eb',
#      'width': 1280,
#      'height': 640,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/KuJtvgK3q4k7cv7a1uoIcg--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/wsj.com/997ad226ccbc25e4a5edead9637689eb',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['GOOG', 'GOOGL', 'MSFT', 'BAIDF', 'BIDU']},
#  {'uuid': '78c797c5-cba9-33c8-adfa-98072b408316',
#   'title': "UPDATE 1-Video gamers renew legal challenge to Microsoft's Activision bid after setback",
#   'publisher': 'Reuters',
#   'link': 'https://finance.yahoo.com/news/1-video-gamers-renew-legal-202359697.html',
#   'providerPublishTime': 1681244639,
#   'type': 'STORY',
#   'relatedTickers': ['MSFT', 'ATVI']},
#  {'uuid': '01add5fb-da1a-3543-b489-130dedf635cc',
#   'title': 'UBS analysts predict extended cloud spending cuts for Microsoft, other tech companies',
#   'publisher': 'Yahoo Finance Video',
#   'link': 'https://finance.yahoo.com/video/ubs-analysts-predict-extended-cloud-202019855.html',
#   'providerPublishTime': 1681244419,
#   'type': 'VIDEO',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/LksCePUIlYpSW_r8ApBwyw--~B/aD0xODg5O3c9MzM2NDthcHBpZD15dGFjaHlvbg--/https://s.yimg.com/os/creatr-uploaded-images/2023-03/43f517a0-d8a6-11ed-b9ff-cf40026689bf',
#      'width': 3364,
#      'height': 1889,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/MBUvm69DITmhA_GCLhU3Ew--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://s.yimg.com/os/creatr-uploaded-images/2023-03/43f517a0-d8a6-11ed-b9ff-cf40026689bf',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['MSFT']},
#  {'uuid': 'f46cbc91-b5f5-47b2-9d77-b15aec100568',
#   'title': 'Meta is ‘giving the market what it wants,’ analyst says',
#   'publisher': 'Yahoo Finance',
#   'link': 'https://finance.yahoo.com/news/meta-is-giving-the-market-what-it-wants-analyst-says-191031349.html',
#   'providerPublishTime': 1681240231,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/eAV_IeyWRPMmmoeKolzv9w--~B/aD0xOTg2O3c9MzA3NTthcHBpZD15dGFjaHlvbg--/https://s.yimg.com/os/creatr-uploaded-images/2023-04/3ddbdbb0-d89c-11ed-bff3-3742d422d9e0',
#      'width': 3075,
#      'height': 1986,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/c.t8WEnmjgPjsSyux3FsMw--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://s.yimg.com/os/creatr-uploaded-images/2023-04/3ddbdbb0-d89c-11ed-bff3-3742d422d9e0',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['GOOG', 'GOOGL', 'META', 'MSFT']},
#  {'uuid': 'c0df3e77-3dc0-36ad-a774-22d81f154e1d',
#   'title': 'Biden Administration Weighs Possible Rules for AI Tools Like ChatGPT',
#   'publisher': 'The Wall Street Journal',
#   'link': 'https://finance.yahoo.com/m/c0df3e77-3dc0-36ad-a774-22d81f154e1d/biden-administration-weighs.html',
#   'providerPublishTime': 1681239300,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/VV8dYZ_BPePBg7Lr32Ahkw--~B/aD02NDA7dz0xMjgwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/wsj.com/10f6bac9537441838ddebe5c0d08f57f',
#      'width': 1280,
#      'height': 640,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/AGdivqPrGcXkYgVHonRcPA--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/wsj.com/10f6bac9537441838ddebe5c0d08f57f',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['MSFT']},
#  {'uuid': '65b53896-faf4-3a06-9d0d-a63cf3c83192',
#   'title': '2023 Top Dow Jones Stocks To Buy And Watch In April: Microsoft Sells Off On Azure Growth Concerns',
#   'publisher': "Investor's Business Daily",
#   'link': 'https://finance.yahoo.com/m/65b53896-faf4-3a06-9d0d-a63cf3c83192/2023-top-dow-jones-stocks-to.html',
#   'providerPublishTime': 1681237593,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/JPX5jeyihDRi4N6ueuYJVQ--~B/aD01NjM7dz0xMDAwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/ibd.com/ed4e9880b0c3e9257977ca3554a6c383',
#      'width': 1000,
#      'height': 563,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/.0m6SEAzHJOxc1V1Vw8fuA--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/ibd.com/ed4e9880b0c3e9257977ca3554a6c383',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['^DJI', 'MSFT', 'AAPL']},
#  {'uuid': '8f38bfe9-9e3c-3e7c-afdf-c31bdfb41cf4',
#   'title': 'Why Fastly Just Popped, but Amazon and Microsoft Dropped',
#   'publisher': 'Motley Fool',
#   'link': 'https://finance.yahoo.com/m/8f38bfe9-9e3c-3e7c-afdf-c31bdfb41cf4/why-fastly-just-popped%2C-but.html',
#   'providerPublishTime': 1681234930,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/8gkvTkZV.Ito3a7gF2e8tw--~B/aD0xMjkwO3c9MjMyMjthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/motleyfool.com/3770d92f645c33e2b64aa53372689891',
#      'width': 2322,
#      'height': 1290,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/_MlJnh_TDaUGrnZKZ7D7Ug--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/motleyfool.com/3770d92f645c33e2b64aa53372689891',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['FSLY', 'AMZN', 'MSFT']}]

# %%
# get option chain for specific expiration
# opt = msft.option_chain('YYYY-MM-DD')
# data available via: opt.calls, opt.puts
